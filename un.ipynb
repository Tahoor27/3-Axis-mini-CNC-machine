# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekpatilpv/3-Axis-mini-CNC-machine/blob/master/un.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as pd
import pandas as pd 
from sklearn import preprocessing,datasets
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/amazon_cr.csv')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %%
df.head()
# Out:
#    id  the  and  a  of  to  is  ...  uch_a  ave_a  n_in_  ied_  nd_b  rso  class.1
# 0   1    5    3  4   4   1   5  ...    NaN    NaN    NaN   NaN   NaN  NaN      NaN
# 1   2   12    3  6   2   3   4  ...    NaN    NaN    NaN   NaN   NaN  NaN      NaN
# 2   3    3    2  2   4   4   2  ...    NaN    NaN    NaN   NaN   NaN  NaN      NaN
# 3   4   18    4  6   5   4   2  ...    NaN    NaN    NaN   NaN   NaN  NaN      NaN
# 4   5   13    4  7   5   4   5  ...    NaN    NaN    NaN   NaN   NaN  NaN      NaN
#
# [5 rows x 10105 columns]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
x = df.iloc[:,0:8]
y = df.Outcome
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0f136e6b56a4> in <module>()
#       1 x = df.iloc[:,0:8]
# ----> 2 y = df.Outcome
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Outcome'

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-32807e7f0689> in <module>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=0)
#
# NameError: name 'x' is not defined
